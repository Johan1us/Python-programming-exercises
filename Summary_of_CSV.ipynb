# 70546      concept   16.0016738        REL  23/12/2016  23/12/2016     prdk
# 70547      concept   17.0011104        REL  31/07/2017  31/07/2017     wnzg
# 70548      concept   17.0012598        REL  01/09/2017  01/09/2017     wnzg
# 70549      concept   18.0005094        REL  28/03/2018  28/03/2018     wnzg
# 70550      concept   18.0008389        REL  22/05/2018  22/05/2018     wnzg
# 70551   F13-000011   13.0005372        Bij  12/12/2013  12/12/2013     aeht
# 70552   F14-002412   14.0004450        REL  10/09/2014  10/09/2014     jtbr
# 70553   F15-003854   15.0013865        REL  26/10/2015  26/10/2015     jtbr
# 70554   F15-004266   15.0006173        REL  01/12/2015  01/12/2015     jtss
# 70555   F15-004267   15.0015556        REL  01/12/2015  01/12/2015     gnrn
# 70556   F16-000128   15.0016375        REL  07/01/2016  07/01/2016     mmmn
# 70557   F16-001317   16.0003177        BIJ  21/03/2016  21/03/2016     JNBR
# 70558   F16-003666   16.0006035        REL  29/09/2016  29/09/2016     anru
# 70559   F17-003494   17.0012311        BIJ  25/08/2017  25/08/2017     mest
# 70560   F17-003495   17.0009956        REL  28/08/2017  28/08/2017     wnzg
# 70561   F17-004199   17.0015218        BIJ  23/10/2017  23/10/2017     eert
# 70562   F18-001537   18.0004112        Bij  18/03/2018  18/03/2018     aasr
# 70563   F18-003061   17.0017513        REL  06/07/2018  06/07/2018     mest
#
#       gebr_bew
# 0         aemn
# 1         eert
# 2         eert
# 3         aemn
# 4         aemn
# 5         nihk
# 6         nihk
# 7         nihk
# 8         aemn
# 9         aemn
# 10        aemn
# 11        aemn
# 12        aemn
# 13        aemn
# 14        aemn
# 15        aemn
# 16        aemn
# 17        aemn
# 18        jbgm
# 19        jbgm
# 20        aemn
# 21        aemn
# 22        aemn
# 23        aemn
# 24        aemn
# 25        aemn
# 26        nihk
# 27        nihk
# 28        nihk
# 29        nihk
# ...        ...
# 70534     fyhn
# 70535     fyhn
# 70536     fyhn
# 70537     fyhn
# 70538     fyhn
# 70539     wnzg
# 70540     wnzg
# 70541     skbr
# 70542     snes
# 70543     anss
# 70544     anss
# 70545     anss
# 70546     prdk
# 70547     wnzg
# 70548     wnzg
# 70549     wnzg
# 70550     wnzg
# 70551     aeht
# 70552     jtbr
# 70553     jtbr
# 70554     jtss
# 70555     gnrn
# 70556     mmmn
# 70557     JNBR
# 70558     anru
# 70559     mest
# 70560     wnzg
# 70561     eert
# 70562     aasr
# 70563     mest
#
# [70564 rows x 7 columns]

# %%
def summary():
  print ('Summary of......:', name_csv + '.csv')
  print ('Columns.........:', len(df.columns))
  print ('Rows............:', len(df.index))
  print (2*('\n'))

  for col in df.columns:
    objcounts = df[(col)].value_counts()
    count_unique = len(objcounts[objcounts != 0])
    print ('  **', (col) ,'**''\n') # print the header of the column
    print ('Rows............:', len(df[(col)].index))
    print ('Filled..........:', df[(col)].count())
    print ('Empty...........:', df[(col)].isna().sum())
    print ('Unique values...:', count_unique)
 
    if df[(col)].count() > 1: # mistake: 'if objcounts.iloc[0] is > 1:'
      high, high_freq = objcounts.index[0], objcounts.iloc[0]
      low, low_freq = objcounts.index[-1], objcounts.iloc[-1] # lowest: trick = -1
      print ('Most freq.......:',high,'  (',high_freq,'x)')
      print ('Least freq......:',low,'  (',low_freq,'x)')
      print ('Datatype........:', df[(col)].dtype) # print the datatype of the column + a new line
      print ('Overview........:''\n')
      head = df[(col)][:5]
      for a in head:
        print ('    ',a)
      print ('     ...')
      tail = df[(col)][-5:]
      for b in tail:
        print ('    ',b)
      print (1*('\n'))
        
    else:
      print ('\n''** This is an empty column **''\n')
  
    if df[(col)].dtype == 'int64':
      objcounts = df[(col)].value_counts()
      count_unique = len(objcounts[objcounts != 0])
      high, high_freq = objcounts.index[0], objcounts.iloc[0]
    
      print ('Min.............:', df[(col)].min())
      print ('Mean............:', df[(col)].mean())
      print ('Max.............:', df[(col)].max())
      print ('Datatype........:', df[(col)].dtype) # print the datatype of the column + a new line
      print ('Overview........:''\n')
      head = df[(col)][:5]
      for a in head:
        print ('    ',a)
      print ('     ...')
      tail = df[(col)][-5:]
      for b in tail:
        print ('    ',b)
      print (1*('\n'))
  
  print (1*('\n'))

# %%
summary()
# Out:
# Summary of......: stuk_stuk.csv
# Columns.........: 7
# Rows............: 70564
#
#
#
#   ** poststuk_id1 **
#
# Rows............: 70564
# Filled..........: 70054
# Empty...........: 510
# Unique values...: 33320
# Most freq.......: 18.0002939   ( 56 x)
# Least freq......: 16.0004405   ( 1 x)
# Datatype........: object
# Overview........:
#
#      nan
#      nan
#      nan
#      nan
#      nan
#      ...
#      F17-003494
#      F17-003495
#      F17-004199
#      F18-001537
#      F18-003061
#
#
#   ** poststuk_id2 **
#
# Rows............: 70564
# Filled..........: 70054
# Empty...........: 510
# Unique values...: 33320
# Most freq.......: 18.0002939   ( 56 x)
# Least freq......: 16.0004405   ( 1 x)
# Datatype........: object
# Overview........:
#
#      17.0001709
#      17.0001895
#      17.0001896
#      17.0001943
#      17.0001944
#      ...
#      17.0012311
#      17.0009956
#      17.0015218
#      18.0004112
#      17.0017513
#
#
#   ** rel_srt_id **
#
# Rows............: 70564
# Filled..........: 70386
# Empty...........: 178
# Unique values...: 6
# Most freq.......: REL   ( 25414 x)
# Least freq......: aan   ( 10 x)
# Datatype........: object
# Overview........:
#
#      BIJ
#      BIJ
#      BIJ
#      BIJ
#      BIJ
#      ...
#      BIJ
#      REL
#      BIJ
#      Bij
#      REL
#
#
#   ** dat_aan **
#
# Rows............: 70564
# Filled..........: 70552
# Empty...........: 12
# Unique values...: 1607
# Most freq.......: 22/02/2018   ( 1484 x)
# Least freq......: 25/03/2008   ( 2 x)
# Datatype........: object
# Overview........:
#
#      13/02/2017
#      15/02/2017
#      15/02/2017
#      15/02/2017
#      15/02/2017
#      ...
#      25/08/2017
#      28/08/2017
#      23/10/2017
#      18/03/2018
#      06/07/2018
#
#
#   ** dat_bew **
#
# Rows............: 70564
# Filled..........: 70552
# Empty...........: 12
# Unique values...: 1607
# Most freq.......: 22/02/2018   ( 1486 x)
# Least freq......: 25/03/2008   ( 2 x)
# Datatype........: object
# Overview........:
#
#      13/02/2017
#      15/02/2017
#      15/02/2017
#      15/02/2017
#      15/02/2017
#      ...
#      25/08/2017
#      28/08/2017
#      23/10/2017
#      18/03/2018
#      06/07/2018
#
#
#   ** gebr_aan **
#
# Rows............: 70564
# Filled..........: 70552
# Empty...........: 12
# Unique values...: 143
# Most freq.......: SYSTEM   ( 11716 x)
# Least freq......: merl   ( 2 x)
# Datatype........: object
# Overview........:
#
#      aemn
#      eert
#      eert
#      aemn
#      aemn
#      ...
#      mest
#      wnzg
#      eert
#      aasr
#      mest
#
#
#   ** gebr_bew **
#
# Rows............: 70564
# Filled..........: 70552
# Empty...........: 12
# Unique values...: 143
# Most freq.......: SYSTEM   ( 11716 x)
# Least freq......: merl   ( 2 x)
# Datatype........: object
# Overview........:
#
#      aemn
#      eert
#      eert
#      aemn
#      aemn
#      ...
#      mest
#      wnzg
#      eert
#      aasr
#      mest

# %%
import sys
sys.stdout = open((name_csv)+'_summary.txt', 'wt')

# %%
summary()
